# %%
# page 320
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# 1. 엑셀파일을 가져와서 판다스 데이터프레임 자료로 전환
df = pd.read_excel('../file_processing/major.xlsx')
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON
# 0   N20   체스게임  김선욱    NaN    88    87      96
# 1   S72  온라인상점  임상호   96.0    77    45      98
# 2   E50    NaN  최진경   84.0    96    87      86
# 3   E50    NaN  황미주   98.0    94   100      97
# 4   C35   풍선게임  김가경   88.0    98    66      68
# 5   E52   다트게임  이원영   50.0    45    50      78
# 6   C35   바둑게임  최성철   80.0    89    92      88
# 7   S72   오목게임  윤성완   98.0    80    78      97
# 8   E50    NaN  김은예   75.0    68    89      45
# 9   N20  온라인상점  이순신   98.0    66   100      97
# 10  N20  온라인상점  강감찬   47.0    60    70      70
# 11  E50    NaN  윤은해   89.0    92    85      85
# 12  E50    NaN  윤은해   89.0    92    85      85
# 13  S72   오목게임  이기자   80.0    80    90      70
# 14  S72   오목게임  금수저  100.0    70    85      85
# 15  S72   오목게임  강남길   80.0    90   100      70
# 16  S72   오목게임  김명현   90.0    80    85      65
# 17  S72   오목게임  주성치   65.0    84    96      80
# 18  C35   바둑게임  최경숙   55.0    98    70      90
# ...

# %%
# 2. 데이터값의 결측치를 탐색
df.isnull().sum()
# Out:
# 전공코드      0
# 프로젝트명     6
# 성명        0
# 글로컬영어     1
# 알고리즘      0
# 자료구조      0
# PYTHON    0
# dtype: int64

# %%
# 3. 열 '글로컬영어'의 결측치를 숫자 정수 0으로 채우시오.
df.fillna({'글로컬영어': 0}, inplace=True)
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON
# 0   N20   체스게임  김선욱    0.0    88    87      96
# 1   S72  온라인상점  임상호   96.0    77    45      98
# 2   E50    NaN  최진경   84.0    96    87      86
# 3   E50    NaN  황미주   98.0    94   100      97
# 4   C35   풍선게임  김가경   88.0    98    66      68
# 5   E52   다트게임  이원영   50.0    45    50      78
# 6   C35   바둑게임  최성철   80.0    89    92      88
# 7   S72   오목게임  윤성완   98.0    80    78      97
# 8   E50    NaN  김은예   75.0    68    89      45
# 9   N20  온라인상점  이순신   98.0    66   100      97
# 10  N20  온라인상점  강감찬   47.0    60    70      70
# 11  E50    NaN  윤은해   89.0    92    85      85
# 12  E50    NaN  윤은해   89.0    92    85      85
# 13  S72   오목게임  이기자   80.0    80    90      70
# 14  S72   오목게임  금수저  100.0    70    85      85
# 15  S72   오목게임  강남길   80.0    90   100      70
# 16  S72   오목게임  김명현   90.0    80    85      65
# 17  S72   오목게임  주성치   65.0    84    96      80
# 18  C35   바둑게임  최경숙   55.0    98    70      90
# ...

# %%
# 4. 열 '프로젝트명'의 결측치를 제거한 후, df 데이터 프레임에 적용하시오
df.dropna(subset='프로젝트명', inplace=True)
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON
# 0   N20   체스게임  김선욱    0.0    88    87      96
# 1   S72  온라인상점  임상호   96.0    77    45      98
# 4   C35   풍선게임  김가경   88.0    98    66      68
# 5   E52   다트게임  이원영   50.0    45    50      78
# 6   C35   바둑게임  최성철   80.0    89    92      88
# 7   S72   오목게임  윤성완   98.0    80    78      97
# 9   N20  온라인상점  이순신   98.0    66   100      97
# 10  N20  온라인상점  강감찬   47.0    60    70      70
# 13  S72   오목게임  이기자   80.0    80    90      70
# 14  S72   오목게임  금수저  100.0    70    85      85
# 15  S72   오목게임  강남길   80.0    90   100      70
# 16  S72   오목게임  김명현   90.0    80    85      65
# 17  S72   오목게임  주성치   65.0    84    96      80
# 18  C35   바둑게임  최경숙   55.0    98    70      90
# 19  N20   체스게임  황진표   75.0    80    60      50
# 20  N20   체스게임  황진표   75.0    80    60      50
# 21  C35   풍선게임  이진호   80.0    74    98     100

# %%
df.isnull().sum()
# Out:
# 전공코드      0
# 프로젝트명     0
# 성명        0
# 글로컬영어     0
# 알고리즘      0
# 자료구조      0
# PYTHON    0
# dtype: int64

# %%
# 5. 중복 데이터가 있는지 확인
df[df.duplicated(keep=False)]
# Out:
#    전공코드 프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON
# 19  N20  체스게임  황진표   75.0    80    60      50
# 20  N20  체스게임  황진표   75.0    80    60      50

# %%
# 6. 중복 데이터를 제거. 제거된 인덱스에 번호 새롭게 부여
df.drop_duplicates(keep=False, ignore_index=True, inplace=True)
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON
# 0   N20   체스게임  김선욱    0.0    88    87      96
# 1   S72  온라인상점  임상호   96.0    77    45      98
# 2   C35   풍선게임  김가경   88.0    98    66      68
# 3   E52   다트게임  이원영   50.0    45    50      78
# 4   C35   바둑게임  최성철   80.0    89    92      88
# 5   S72   오목게임  윤성완   98.0    80    78      97
# 6   N20  온라인상점  이순신   98.0    66   100      97
# 7   N20  온라인상점  강감찬   47.0    60    70      70
# 8   S72   오목게임  이기자   80.0    80    90      70
# 9   S72   오목게임  금수저  100.0    70    85      85
# 10  S72   오목게임  강남길   80.0    90   100      70
# 11  S72   오목게임  김명현   90.0    80    85      65
# 12  S72   오목게임  주성치   65.0    84    96      80
# 13  C35   바둑게임  최경숙   55.0    98    70      90
# 14  C35   풍선게임  이진호   80.0    74    98     100

# %%
# 7. 아래 데이터를 인덱스 15번 행 위치에 추가
df.loc[15] = ['N20', '온라인게임', '은지원', 90.0, 80, 80, 80]
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON
# 0   N20   체스게임  김선욱    0.0    88    87      96
# 1   S72  온라인상점  임상호   96.0    77    45      98
# 2   C35   풍선게임  김가경   88.0    98    66      68
# 3   E52   다트게임  이원영   50.0    45    50      78
# 4   C35   바둑게임  최성철   80.0    89    92      88
# 5   S72   오목게임  윤성완   98.0    80    78      97
# 6   N20  온라인상점  이순신   98.0    66   100      97
# 7   N20  온라인상점  강감찬   47.0    60    70      70
# 8   S72   오목게임  이기자   80.0    80    90      70
# 9   S72   오목게임  금수저  100.0    70    85      85
# 10  S72   오목게임  강남길   80.0    90   100      70
# 11  S72   오목게임  김명현   90.0    80    85      65
# 12  S72   오목게임  주성치   65.0    84    96      80
# 13  C35   바둑게임  최경숙   55.0    98    70      90
# 14  C35   풍선게임  이진호   80.0    74    98     100
# 15  N20  온라인게임  은지원   90.0    80    80      80

# %%
# 8. 열에 '총점'을 추가한 후, 총점을 구하시오.
# 총점 = '글로컬영어' + '알고리즘' + '자료구조' + 'PYTHON'
df['총점'] = df['글로컬영어'] + df['알고리즘'] + df['자료구조'] + df['PYTHON']
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점
# 0   N20   체스게임  김선욱    0.0    88    87      96  271.0
# 1   S72  온라인상점  임상호   96.0    77    45      98  316.0
# 2   C35   풍선게임  김가경   88.0    98    66      68  320.0
# 3   E52   다트게임  이원영   50.0    45    50      78  223.0
# 4   C35   바둑게임  최성철   80.0    89    92      88  349.0
# 5   S72   오목게임  윤성완   98.0    80    78      97  353.0
# 6   N20  온라인상점  이순신   98.0    66   100      97  361.0
# 7   N20  온라인상점  강감찬   47.0    60    70      70  247.0
# 8   S72   오목게임  이기자   80.0    80    90      70  320.0
# 9   S72   오목게임  금수저  100.0    70    85      85  340.0
# 10  S72   오목게임  강남길   80.0    90   100      70  340.0
# 11  S72   오목게임  김명현   90.0    80    85      65  320.0
# 12  S72   오목게임  주성치   65.0    84    96      80  325.0
# 13  C35   바둑게임  최경숙   55.0    98    70      90  313.0
# 14  C35   풍선게임  이진호   80.0    74    98     100  352.0
# 15  N20  온라인게임  은지원   90.0    80    80      80  330.0

# %%
# 9. 열에 '평균'을 추가한 후, 평균을 구하시오.
# 평균 = 총점 / 4
df['평균'] = df['총점'] / 4
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점     평균
# 0   N20   체스게임  김선욱      0    88    87      96  271.0  67.75
# 1   S72  온라인상점  임상호     96    77    45      98  316.0  79.00
# 2   C35   풍선게임  김가경     88    98    66      68  320.0  80.00
# 3   E52   다트게임  이원영     50    45    50      78  223.0  55.75
# 4   C34   바둑게임  최성철     80    89    92      88  349.0  87.25
# 5   S72   오목게임  윤성완     98    80    78      97  353.0  88.25
# 6   N20  온라인상점  이순신     98    66   100      97  361.0  90.25
# 7   N20  온라인상점  강감찬     47    60    70      70  247.0  61.75
# 8   S72   오목게임  이기자     80    80    90      70  320.0  80.00
# 9   S72   오목게임  금수저    100    70    85      85  340.0  85.00
# 10  S72   오목게임  강남길     80    90   100      70  340.0  85.00
# 11  S72   오목게임  김명현     90    80    85      65  320.0  80.00
# 12  S72   오목게임  주성치     65    84    96      80  325.0  81.25
# 13  C34   바둑게임  최경숙     55    98    70      90  313.0  78.25
# ...

# %%
# 10. 글로컬영어의 실수형 자료형을 정수형 자료형으로 수정하시오.
df['글로컬영어'] = df['글로컬영어'].astype(int)
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점     평균
# 0   N20   체스게임  김선욱      0    88    87      96  271.0  67.75
# 1   S72  온라인상점  임상호     96    77    45      98  316.0  79.00
# 2   C35   풍선게임  김가경     88    98    66      68  320.0  80.00
# 3   E52   다트게임  이원영     50    45    50      78  223.0  55.75
# 4   C34   바둑게임  최성철     80    89    92      88  349.0  87.25
# 5   S72   오목게임  윤성완     98    80    78      97  353.0  88.25
# 6   N20  온라인상점  이순신     98    66   100      97  361.0  90.25
# 7   N20  온라인상점  강감찬     47    60    70      70  247.0  61.75
# 8   S72   오목게임  이기자     80    80    90      70  320.0  80.00
# 9   S72   오목게임  금수저    100    70    85      85  340.0  85.00
# 10  S72   오목게임  강남길     80    90   100      70  340.0  85.00
# 11  S72   오목게임  김명현     90    80    85      65  320.0  80.00
# 12  S72   오목게임  주성치     65    84    96      80  325.0  81.25
# 13  C34   바둑게임  최경숙     55    98    70      90  313.0  78.25
# ...

# %%
# 11. 열 '전공코드' C35의 '프로젝트명'이 '바둑게임'인 '전공코드'를 'C34'로 모두 대체 하시오.
df.loc[(df['전공코드'] == 'C35') & (df['프로젝트명'] == '바둑게임'), '전공코드'] = 'C34'
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점     평균
# 0   N20   체스게임  김선욱      0    88    87      96  271.0  67.75
# 1   S72  온라인상점  임상호     96    77    45      98  316.0  79.00
# 2   C35   풍선게임  김가경     88    98    66      68  320.0  80.00
# 3   E52   다트게임  이원영     50    45    50      78  223.0  55.75
# 4   C34   바둑게임  최성철     80    89    92      88  349.0  87.25
# 5   S72   오목게임  윤성완     98    80    78      97  353.0  88.25
# 6   N20  온라인상점  이순신     98    66   100      97  361.0  90.25
# 7   N20  온라인상점  강감찬     47    60    70      70  247.0  61.75
# 8   S72   오목게임  이기자     80    80    90      70  320.0  80.00
# 9   S72   오목게임  금수저    100    70    85      85  340.0  85.00
# 10  S72   오목게임  강남길     80    90   100      70  340.0  85.00
# 11  S72   오목게임  김명현     90    80    85      65  320.0  80.00
# 12  S72   오목게임  주성치     65    84    96      80  325.0  81.25
# 13  C34   바둑게임  최경숙     55    98    70      90  313.0  78.25
# ...

# %%
# 12. 열 '전공코드' 기준 오름차순으로 정렬하시오.
df.sort_values(by=['전공코드'], ascending=True)
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점     평균
# 4   C34   바둑게임  최성철     80    89    92      88  349.0  87.25
# 13  C34   바둑게임  최경숙     55    98    70      90  313.0  78.25
# 2   C35   풍선게임  김가경     88    98    66      68  320.0  80.00
# 14  C35   풍선게임  이진호     80    74    98     100  352.0  88.00
# 3   E52   다트게임  이원영     50    45    50      78  223.0  55.75
# 0   N20   체스게임  김선욱      0    88    87      96  271.0  67.75
# 6   N20  온라인상점  이순신     98    66   100      97  361.0  90.25
# 7   N20  온라인상점  강감찬     47    60    70      70  247.0  61.75
# 15  N88  온라인게임  은지원     90    80    80      80  330.0  82.50
# 1   S72  온라인상점  임상호     96    77    45      98  316.0  79.00
# 5   S72   오목게임  윤성완     98    80    78      97  353.0  88.25
# 8   S72   오목게임  이기자     80    80    90      70  320.0  80.00
# 9   S72   오목게임  금수저    100    70    85      85  340.0  85.00
# 10  S72   오목게임  강남길     80    90   100      70  340.0  85.00
# ...

# %%
# 13. 열 '전공코드' 기준으로 그룹화 하시오.
df.groupby(['전공코드']).sum()
# Out:
#                               프로젝트명                     성명  글로컬영어  알고리즘  자료구조  \
# 전공코드
# C34                        바둑게임바둑게임                 최성철최경숙    135   187   162
# C35                        풍선게임풍선게임                 김가경이진호    168   172   164
# E52                            다트게임                    이원영     50    45    50
# N20                  체스게임온라인상점온라인상점              김선욱이순신강감찬    145   214   257
# N88                           온라인게임                    은지원     90    80    80
# S72   온라인상점오목게임오목게임오목게임오목게임오목게임오목게임  임상호윤성완이기자금수저강남길김명현주성치    609   561   579
#
#       PYTHON      총점      평균
# 전공코드
# C34      178   662.0  165.50
# C35      168   672.0  168.00
# E52       78   223.0   55.75
# N20      263   879.0  219.75
# N88       80   330.0   82.50
# S72      565  2314.0  578.50

# %%
# 14. 그룹화된 '전공코드'를 기반으로 '총점'에 대한 원형 그래프를 완성하시오.
# 단, 그래프 제목은 '학부 전공 성적 summary'로 글자색은 파랑, 글자크기는 20이다.
plt.rcParams['font.family'] = ['AppleGothic']
plt.title('학부 전공 성적 summary', color='blue', fontsize=20)
label = df[df['전공코드']]
plt.pie(df, labels=label)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[132], line 5
#       3 plt.rcParams['font.family'] = ['AppleGothic']
#       4 plt.title('학부 전공 성적 summary', color='blue', fontsize=20)
# ----> 5 label = df[df['전공코드']]
#       6 plt.pie(df, labels=label)
#
# File ~/.virtualenvs/day1/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.virtualenvs/day1/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
# 응용1. df['전공코드']가 N20이고 프로젝트명이 온라인게임인 데이터 코드를 무조건 N88로 변경
df.loc[(df['전공코드'] == 'N20') & (df['프로젝트명'] == '온라인게임'), '전공코드'] = 'N88'
df
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점     평균
# 0   N20   체스게임  김선욱      0    88    87      96  271.0  67.75
# 1   S72  온라인상점  임상호     96    77    45      98  316.0  79.00
# 2   C35   풍선게임  김가경     88    98    66      68  320.0  80.00
# 3   E52   다트게임  이원영     50    45    50      78  223.0  55.75
# 4   C34   바둑게임  최성철     80    89    92      88  349.0  87.25
# 5   S72   오목게임  윤성완     98    80    78      97  353.0  88.25
# 6   N20  온라인상점  이순신     98    66   100      97  361.0  90.25
# 7   N20  온라인상점  강감찬     47    60    70      70  247.0  61.75
# 8   S72   오목게임  이기자     80    80    90      70  320.0  80.00
# 9   S72   오목게임  금수저    100    70    85      85  340.0  85.00
# 10  S72   오목게임  강남길     80    90   100      70  340.0  85.00
# 11  S72   오목게임  김명현     90    80    85      65  320.0  80.00
# 12  S72   오목게임  주성치     65    84    96      80  325.0  81.25
# 13  C34   바둑게임  최경숙     55    98    70      90  313.0  78.25
# ...

# %%
# 응용2. 4과목(글로컬영어, 알고리즘, 자료구조, PYTHON) 점수가 모두 80점 이상인 데이터를 조회
df[(df['글로컬영어'] >= 80) & (df['알고리즘'] >= 80) & (df['자료구조'] >= 80) & (df['PYTHON'] >= 80)]
# Out:
#    전공코드  프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점     평균
# 4   C34   바둑게임  최성철     80    89    92      88  349.0  87.25
# 15  N88  온라인게임  은지원     90    80    80      80  330.0  82.50

# %%
# 응용3. 성명이 김씨 성을 가진 사람을 조회
# HINT df['성명'].str.contains('김')
df[df['성명'].str.contains('김')]
# Out:
#    전공코드 프로젝트명   성명  글로컬영어  알고리즘  자료구조  PYTHON     총점     평균
# 0   N20  체스게임  김선욱      0    88    87      96  271.0  67.75
# 2   C35  풍선게임  김가경     88    98    66      68  320.0  80.00
# 11  S72  오목게임  김명현     90    80    85      65  320.0  80.00

# %%
df.pivot_table(index='전공코드', values='자료구조')
# Out:
#            자료구조
# 전공코드
# C34   81.000000
# C35   82.000000
# E52   50.000000
# N20   85.666667
# N88   80.000000
# S72   82.714286

# %%
df.pivot_table(index='전공코드', values='자료구조', aggfunc=['sum', 'mean'])
# Out:
#       sum       mean
#      자료구조       자료구조
# 전공코드
# C34   162  81.000000
# C35   164  82.000000
# E52    50  50.000000
# N20   257  85.666667
# N88    80  80.000000
# S72   579  82.714286

# %%
df.pivot_table(index='전공코드', values='자료구조', aggfunc=['sum', 'mean', 'max'])
# Out:
#       sum       mean  max
#      자료구조       자료구조 자료구조
# 전공코드
# C34   162  81.000000   92
# C35   164  82.000000   98
# E52    50  50.000000   50
# N20   257  85.666667  100
# N88    80  80.000000   80
# S72   579  82.714286  100

# %%
# 알고리즘과 자료구조에 대한 합계, 평균, 최대값, 최소값으로 피벗테이블로 행기준 요약
df.pivot_table(index=['전공코드'], values=['알고리즘', '자료구조'], aggfunc=['sum', 'mean', 'max', 'min'])
# Out:
#       sum            mean             max       min
#      알고리즘 자료구조       알고리즘       자료구조 알고리즘 자료구조 알고리즘 자료구조
# 전공코드
# C34   187  162  93.500000  81.000000   98   92   89   70
# C35   172  164  86.000000  82.000000   98   98   74   66
# E52    45   50  45.000000  50.000000   45   50   45   50
# N20   214  257  71.333333  85.666667   88  100   60   70
# N88    80   80  80.000000  80.000000   80   80   80   80
# S72   561  579  80.142857  82.714286   90  100   70   45
